# %% [markdown]
# # Exercice 1
#
# 1. Quels sont les langages à utiliser pour réaliser les actions suivantes :
#     * Mettre les titres en gras, en rouge et les souligner
#     * Insérer une image dans la page web
#     * Compter le nombres de visiteur de la page
#     * Mettre un hyperlien
#     * Créer un paragraphe avec du texte
#     * Positionner une image à l'endroit voulu sur la page
#     * Créer un bouton "Valider" sur lequel on peut cliquer
#     * Rédiger les questions d'un QCM en ligne (avec des cases à cocher)
#     * Corriger les réponses d'un QCM en ligne et calculer la note obtenue
#
#
# 2. Classez les 3 langages du web (HTML, CSS, Javascript) dans 2 catégories :
#     * Langage de description
#     * Langage de programmation
#
# # Avertissement
#
# > Les informaticiens doivent lire beaucoup de documentation pour trouver de l'information : ça fait partie du travail de développeur. Ceci est d'autant plus vrai en développement web car le nombre de balises HTML, d'attributs de balises et leurs valeurs possibles ainsi que la multitude de propriétés CSS est gigantesque. Pour cela, il faut se rendre sur des sites de référence dont l'information est particulièrement fiable, complète et à jour plutôt que sur les forums où on trouve tout et n'importe quoi ou se précipiter sur une recherche google. <br/><br/> Pour faire le travail demandé ici, vous allez souvent vous poser ce genre de questions (et c'est normal) :
# * Quelle est la balise que je dois utiliser ?
# * Comment je fais ça ?
# * etc...
# <br/> **Vous devez faire preuve d'AUTONOMIE ET CHERCHER PAR VOUS-MEME. Le premier endroit où chercher est le site du [Mozilla Development Network ou MDN](https://developer.mozilla.org/fr/).** Cela m'étonnerait beaucoup que vous n'y trouvez pas ce que vous rechercher. Il y a d'autres ressources disponibles dans `/premiere/Outils_et_environnement_informatiques/Bibliographie_webographie` et dans `/premiere/Outils_et_environnement_informatiques/memento_HTML`
# ![menu du MDN](img/mdn.png)
#
#
# # Exercice 2
# (*D'après [FIL](https://www.fil.univ-lille1.fr/)*)
#
#
# 1. Télécharger le fichier `premier.html` depuis github dans le répertoire `/home`.
#
#
# 2. Ouvrir ce fichier dans le navigateur. Lisez-le
#
#
# 3. Ouvrir ce fichier dans **Atom** pour afficher son code source (garder le fichier ouvert dans votre navigateur).
#
#
# 4. Vérifiez à l'aide du [validateur](https://validator.w3.org/nu/) que la syntaxe de cette page est correcte.
#
#
# 5. Ouvrir le site https://developer.mozilla.org/fr/docs/Glossaire/Entity pour répondre aux questions suivantes :
#     * On trouve dans le fichier `premier.html` cette syntaxe `&#xA0;` et `&lt;`. A quel affichage cela correspond-il ?
#     * Pourquoi ne pas avoir utilisé le symbole `<` plutôt que `&lt;` ? Expliquer la raison
#
#
# 6. Rechercher dans le site du **MDN** les balises suivantes `<code>` `<q>` `<abbr>`. Quelle **signification** ces balises donnent-elles à l'élément qu'elles encadrent ?
#
#
# 7. A quoi sert l'attribut `<title>` de la balise `<abbr>` ? Observez son action dans le navigateur.
#
#
# # Exercice 3
# (*D'après [FIL](https://www.fil.univ-lille1.fr/)*)
#
# 1. Comme dans l'exercice précédent, chargez le fichier `premier-corrompu.html` dans le **navigateur** et dans **Atom**. Parvenez-vous à le visualiser "normalement"  dans le navigateur ?
#
# > **Rappel du cours :** Les premières pages que vous écrirez seront très simples. Dans ce cas, le navigateur peut "rattraper" des erreurs dans la syntaxe ou la structure d'un fichier HTML.
# Mais ne vous faîtes pas d'illusion, pour des "vraies" page web (notamment dès qu'on ajoute des feuilles de style CSS et du code javascript), les erreurs de syntaxe engendreront des dysfonctionnements ou des problèmes d'affichage. Il peut aussi y avoir d'autres conséquences sur le **référencement** de votre page web par les moteurs de recherche.
#
# 2. Testez-le avec le validateur. Combien d'erreurs sont signalées ?
#
#
# 3. Qu'indique le message de la première erreur signalée ?
#
#
# 4. A quelle ligne et sur quelle portion du code source est-elle signalée ?
#
#
# 5. A quoi est due cette erreur ?
#
#
# 6. Corrigez-la et repassez le document au validateur.
#
#
# >La touche F5 permet un rechargement de la page et donc de tester la validation du même document avec les mêmes options.
#
# 7. Lisez les messages d'erreur suivants en essayant d'en comprendre le message et de les localiser dans le fichier source.
#
#
# 8. Corrigez une à une les erreurs signalées. Testez la validité après chaque correction (et donc vérifiez votre correction).
# (*Pour chaque erreur décrivez concisément et précisément la cause de l'erreur.*)
#
#
#
# # Exercice 4
#
# **ATTENTION : ce travail doit être fait dans un dossier qui s'appelle `HTML_exercice4`. L'image `googleplex.jpeg` doit être téléchargée depuis github et mise dans ce dossier**
#
# > On souhaite obtenir la page HTML ci-dessous. Le mot ici est un hyperlien qui mène vers la page d'acceuil de google
# ![affichage souhaité](img/affichageSouhaite.png)
#
#
# Un élève écrit le code suivant...
# ```html
# <img alt="Siège social de google">
# <p>Cliquer ici pour effectuer une recherche</p>
# ```
#
# ... et obtient l'affichage ci-dessous
# ![affichage obtenu](img/affichageObtenu.png)
#
# 1. A quoi sert l'attribut `alt` ? Expliquer pourquoi le navigateur écrit le texte "Siège social de google" plutôt que d'afficher l'image
#
#
# 2. Corriger le code de l'élève afin d'obtenir l'affichage souhaité
#
#
# 3. Créer un dossier `img` dans le dossier où se trouve votre fichier html. Puis déplacez-y l'image `googleplex.jpeg`.
#
# > Vous devriez constater que l'image ne s'affiche plus et est remplacé par le texte alternatif
#
#
# 4. Corriger le code afin d'obtenir l'affichage de l'image. Pour cela, vous devez corriger le [**chemin**](https://fr.wikipedia.org/wiki/Chemin_d%27acc%C3%A8s) qui permet d'aller chercher l'image depuis l'endroit où se situe le ficher html (cela s'appelle un **chemin relatif**)
#
# > N'oubliez pas de **sauvegarder votre travail** dans votre _repository_ sur github. Il doit être contenu dans un dossier `HTML_exercice4` "rangé" au bon endroit de votre _repository_
#
#
# # Exercice 5
#
# > On souhaite écrire le code HTML permettant d'établir la liste imbriquée ci-dessous (qui peut par exemple être reprise dans un menu de navigation)
#
# ![listes imbriquées](img/listesImbriquees.png)
#
# 1. Quel type de balise doit-on utiliser : `<ol>` ou `<ul>` ?
#
#
# 2. Chercher dans le site du [Mozilla Development Network](https://developer.mozilla.org/fr/) la page donnant les explications sur le type de balise que vous avez choisi à la première question
#
#
# 3. Quel est l'**attibut** à utiliser pour choisir le type de numérotation d'une liste ?
#
#
# 4. Ecrire le code HTML de la liste dans un fichier `HTML_exercice5`. Pour cela, suivre les conseils suivants :
#     * Sur le site du [MDN](https://developer.mozilla.org/fr/) bien lire la partie sur les listes imbriquées, notamment les exemples
#     * On peut être vite "perdu" dans l'écriture du code si on ne fait pas apparaître visuellement les imbrications de liste dans le code HTML lui-même avec des **indentations** (ou **tabulations**) et des **alignements** cohérents. Atom vous aide mais ne fait pas tout le travail correctement : à vous d'être vigilant !
#
# > N'oubliez pas de **sauvegarder votre travail** dans votre _repository_ sur github. Il doit être contenu dans un dossier `HTML_exercice5` "rangé" au bon endroit de votre _repository_
