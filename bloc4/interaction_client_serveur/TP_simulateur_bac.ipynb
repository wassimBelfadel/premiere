# %% [markdown]
# # Simulateur de bac
#
# ## Objectif
#
# Calculer la note obtenue au baccalauréat en fonction des résultats des élèves. Le traitement se fera en **javascript, c'est-à-dire côté client**
#
# * Première :
#     * Moyenne des 3 bulletins de première : 5
#     * Histoire-Géo, LVA, LVB : 2.5 chacun (soit 1.25 pour chaque note des deux sessions...)
#     * Enseignement Scientifique : 2.5
#     * Spécialité abandonnée : 5
#     * Français écrit et oral : 5 chacun
#
#
# * Terminale :
#     * Moyenne des 3 bulletins de terminale : 5
#     * Histoire-Géo, LVA et LVB : 2.5
#     * Enseignement Scientifique : 2.5
#     * EPS : 5
#     * Spécialités : 16 chacune
#     * Philo : 8
#     * Grand oral : 10
#
# La somme des coefficients est, bien entendu, égale à 100.
#
#
# # Travail à faire
#
# Télécharger les fichiers `simulateur_bac.html`, `style.css` et `script.js`.
#
#
# ## Formulaire HTML
#
# Compléter le fichier `simulateur_bac.html` afin que le formulaire ressemble à la figure ci-dessous. (Il n'y aura aucune modification à apporter au fichier `style.css` dont le but est de présenter le formulaire en 2 colonnes.)
# **Sachant que le traitement se fait en Javascript côté client, utiliser uniquement les attributs nécessaires !!**
#
# ![simulateur de bac](img/simulateur.png)
#
#
# ## Traitement du formulaire en Javascript (côté client)
#
# **Pour réaliser cette partie, il faudra utiliser les connaissances vue en PROGRAMMATION EVENEMENTIELLE (BLOC4)**
#
# ### Objectif
#
# Le but de cette partie est de :
# * calculer la moyenne obtenue au baccalauréat à partir des notes entrées par le visiteur
# * générer une fenêtre "Pop-up" informant le visiteur du résultat de la simulation (la moyenne obtenue par le visiteur - voir figure ci-dessous)
#
# ![alert](img/alert.png)
#
#
#
# ### Travail à faire
#
# Complétez le fichier `script.js` (et n'oubliez pas de "déclarer" le fichier `script.js` dans le fichier HTML).
#
# Conseils :
# * Des commentaires dans le fichier devraient vous aider...
# * Ne chercher pas à écrire du code javascript très abouti : je rappelle qu'on n'exige pas de vous le même niveau en javascript et en python...
