# %% [markdown]
# # Partie 1 - code javascript dans l'HTML : "syntaxe  `onevent`"
#
# > Cette syntaxe est plus simple pour l'apprentissage de javascript, c'est d'ailleurs celle majoritairement utilisée dans l'épreuve de QCM. Néanmoins, elle possède certaines limitations et n'est donc plus recommandée. On verra une autre syntaxe plus évoluée par la suite.
#
# Télécharger le fichier `javascript.html` depuis le dépôt sur github, déplacer-le dans `/home` puis renommer-le en `javacript1.html`. **Lire ce fichier : c'est votre cours !!**
# (**Conseil : faire cela avec un terminal plutôt qu'avec l'explorateur graphique de fichier pour réviser les lignes de commandes !!**)
#
# Vous allez maintenant rendre cette page dynamique en la modifiant lorsque quelques événements apparaissent
#
# > Ouvrir le fichier `javascript1.html` dans ATOM afin de pouvoir faire les modifications (Elles concerneront toutes la dernière partie de la page web appelée "Exemples")
#
# ## Activité 1
#
# 1. Apporter les modifications suivantes au document `javascript1.html`
#
# ```html
#   <p onclick="window.alert('une fonction javascript qui affiche une fenêtre pop-up !!')">Un événement "clic" sur cette phrase (paragraphe cible) va déclencher...</p>
#
# ```
#
# 2. Tester le résultat dans le navigateur
#
#
# ## Activité 2
#
# 1. Apporter les modifications suivantes au document `javascript1.html`
#
# ```html
#   <p onclick="popUp()">Un événement "clic" sur cette phrase (paragraphe cible) va déclencher...</p>
# ```
#
# 2. Ajouter à la fin du document **juste avant** la balise `</body>`
#
# ```html
#   <script>
#       function popUp() {
#         window.alert("une fonction javascript qui affiche une fenêtre pop-up !!");
#       }
#   </script>
# ```
#
# 3. Tester le résultat dans le navigateur
#
#
# ## Activité 3
#
# 1. Apporter les modifications suivantes au document `javascript1.html`
#
# ```html
#   <p onclick="popUp()">Un événement "clic" sur cette phrase (paragraphe cible) va déclencher...</p>
# ```
#
# 2. Supprimer :
#
# ```html
#   <script>
#       function popUp() {
#         window.alert("une fonction javascript qui affiche une fenêtre pop-up !!");
#       }
#   </script>
# ```
#
# 3. Ajouter à la fin du document **juste avant** la balise `</body>`
#
# ```html
#   <script src="script1.js"></script>
# ```
#
# 4. Créer dans ATOM un nouveau fichier `script1.js` contenant le code suivant :
#
# ```js
#     function popUp() {
#         window.alert("une fonction javascript qui affiche une fenêtre pop-up !!");
#         }
# ```
#
# 5. Tester le résultat dans le navigateur
#
# Y a-t-il une différence de comportement de la page web entre les 3 activités ?
# Que pouvez-vous dire sur `onclick` ? `popUp` ?
#
#
#
# ## Synthèse intermédiaire
#
# ### Programmation des événements
#
# * _on**event**_ est un **attribut**  permettant de spécifier l'événement qui nous intéresse. Comme tout attribut HTML, _on**event**_ est noté dans la balise ouvrannte de la **cible**. Par exemple `onclick`, `onmouseover` etc...
#
#
# * la valeur de cet attribut correspond au code javascript qui sera exécuté lorsque l'événement apparaît. Il est plus lisible de mettre comme code javascript un simple **appel de fonction**
#
#
# * Le corps de la fonction est écrit entre des balises `<script> </script>`. Le tout placé juste avant la balise `</body>` (comme dans l'activité 2)
#
#
# * Il est encore plus clair d'écrire le code javascript dans un fichier séparé d'extension **.js**. Dans ce cas, on mettra juste avant la balise `</body>` le _lien_ vers le fichier javascript
#
# ### Quelques caractéristiques du langage javascript
#
# > Javascipt possède beaucoup de similitudes avec python et quelques différences. L'apprentissage de javascript demande beaucoup de temps, que nous n'avons pas en NSI : On n'attend pas de vous la même maîtrise en javascript et en python !
#
# * javascript est un langage **orienté objet** utilisant la notation pointée (comme python). l'objet `window` représente la fenêtre du navigateur. `window.alert` permet d'appeler une méthode (ou fonction) `alert` qui affiche une nouvelle fenêtre "popup" dans la fenêtre `window`. La fonction `alert` prend en paramètre une chaîne de caractères correspondant au texte affiché dans la fenêtre "popup"
#
#
# * chaque instruction doit être suivie d'un `;`
#
#
# * **ce n'est pas l'indentation qui structure le code** : les instructions d'un même bloc de code sont ici encadrées par des accolades : `{` .... `}`
#
#
# * les commentaires sont précédées d'un double-slash : `//`
#
# ### Développement en javascript
#
# Pour coder en JavaScript, un simple éditeur de texte suffit (vous utiliserez là-aussi ATOM). Par contre, le débogage est moins évident : il faudra aller consulter les messages d'erreur directement dans la console du navigateur.
#
# Pour la faire apparaître, faites **CTRL + MAJ + K** dans la page du navigateur.
#
# ![console](img/console_js.png)
#
#
# ## Activité 4
#
#
# 1. Apporter les modifications suivantes au document `javascript1.html`
#
# ```html
#   <li id="monItem1" ondblclick="modifierItem()">Un événement "double clic" sur cet item de liste va déclencher...</li>
#
# ```
#
# 2. Ajouter dans le fichier `script1.js` le code suivant :
#
# ```js
#     function modifierItem(){
#         document.getElementById("monItem1").innerHTML="...une fonction javascript qui le modifie";
#       }
# ```
#
# 3. Tester le résultat dans le navigateur
#
#
# ## Activité 5
#
#
# 1. Apporter les modifications suivantes au document `javascript1.html`
#
# ```html
#   <li id="monItem2" onmouseover="changeColor()">Un événement "survol de la souris" sur cet item de liste va déclencher du code javascript qui en change la couleur</li>
#
# ```
#
# 2. Ajouter dans le fichier `script1.js` le code suivant :
#
# ```js
#     function changeColor(element){
#         document.getElementById("monItem2").style.color="blue";
#       }
# ```
#
# 3. Tester le résultat dans le navigateur
#
#
# ## Activité 6
#
#
# 1. Apporter les modifications suivantes au document `javascript1.html`
#
# ```html
#   <button type="button" onclick="permuter()">Permuter les photos</button>
#
# ```
#
# 2. Ajouter dans le fichier `script1.js` le code suivant :
#
# ```js
#     function permuter(){
#         document.getElementById("image1").src = "img/logoJS.png";
#         document.getElementById("image2").src = "img/BrendanEich.jpg";
#       }
# ```
#
# 3. Tester le résultat dans le navigateur
#
#
# ## Synthèse intermédiaire
#
# * L'objet `document` représente le code HTML de la page web (plus précisément son arbre DOM)
#
#
# * La méthode `getElementById` permet de **sélectionner un élément HTML** identifié par son **`id`**. Une fois qu'on a sélectionner un élément HTML, on peut accéder à un de ses **attributs** HTML.
# Par exemple `document.getElementById("image2").src` permet d'accéder à l'attribut `src` (représentant le chemin vers le fichier image) de l'élément HTML d'id `"image2`
#
#
# * `innerHTML` permet d'accéder au **contenu d'un élément HTML** ("ce qu'il y a entre les balises ouvrantes et fermantes")
#
#
# * Pour modifier le style CSS d'un élément HTML `elmt.style.propriété = "attribut"`. Les valeurs à utiliser pour la règle de style (propriété et attribut) sont exactement les mêmes que celle utilisées dans les feuilles CSS (voir le cours sur le CSS si besoin)
# Par exemple `document.getElementById("monItem2").style.color="blue"` permet de mettre un style couleur bleue au texte de l'élément HTML d'id `"monItem2"`
#
#
# ## Activité 7
#
# L'appui sur le bouton _permuter les photos_ ne fonctionne pas correctement (seul le premier clic fonctionne). Ce qui est normal compte tenu de la fonction `permuter`
#
# Après avoir compris pourquoi ce comportement "étrange", corriger le code de la fonction `permuter` afin d'avoir un fonctionnement correct.
#
#
# ## Activité 8
#
# La dernière phrase du fichier `javascript1.html` est celle-ci **Tappez sur nimporte quelle touche pour remettre la page dans son état initial**
#
# On se propose de réaliser cette action en programmation événementielle. En recherchant dans la [liste des événements](https://developer.mozilla.org/fr/docs/Web/Events), chercher celui le plus adapté à notre cas. Quel élément HTML cible choisir ? Ecrire le code nécessaire et tester.
#
#
# ## Activité 9
#
# > Pour retenir, il faut pratiquer !!
#
# Programmer 3 autres actions dynamiques en javascript (à vous de les choisir) sur **3 événements et 3 éléments cibles** différents. Il faudra bien sûr écrire les **3 fonctions javascript** correspondantes. Faîtes vérifier votre travail !
#
# *(Conseil : Faîtes des choses simples car nous n'avons vu que la base en javascript !!)*
#
#
# # Partie 2 - séparation du code javascript de l'HTML : "syntaxe  `event`"
#
# > La syntaxe précédente possède certaines limitations et inconvénients, notamment le fait de mêler du code javascript dans le fichier HTML. Dans cette partie, on va voir une autre façon de faire, recommandée, qui évite cela.
#
# Télécharger le fichier `javascript.html` depuis le dépôt sur github, déplacer-le dans `/home` puis renommer-le en `javacript2.html`.
# (**Conseil : faire cela avec un terminal plutôt qu'avec l'explorateur graphique de fichier pour réviser les lignes de commandes !!**)
#
#
# ## Activité 10
#
# 1. Ajouter à la fin du document `javacript2.html` **juste avant** la balise `</body>`
#
# ```html
#   <script src="script2.js"></script>
# ```
#
# 2. Créer dans ATOM un nouveau fichier `script2.js` et y copier toutes les fonctions contenues dans le fichier `script1.js`
#
# 3. Ajouter les lignes de code suivantes au fichier `script2.js`
#
# ```js
#     document.getElementById("monItem1").addEventListener("dblclick",modifierItem);
#     document.getElementById("monItem2").addEventListener("mouseover",changeColor);
# ```
#
# 4. Tester le résultat dans le navigateur
#
# ## Synthèse intermédiaire
#
# La méthode `addEventListener` permet d'**abonner des fonctions gestionnaires d'événements à un élément cible**. Attention à la syntaxe :
# * "syntaxe `event` plutôt que syntaxe `onevent`"
#
#
# * Il ne s'agit pas d'appeler la fonction mais de l'abonner : il ne faut donc pas mettre de parenthèses au niveau des paramètres de la fonction !!
#
#
# ## Activité 11
#
# > Vous avez dû constater que quelques fonctionnalités attendues sont inopérantes. En effet : 3 abonnements n'ont été pas faits ! C'est l'objet de cette activité.
# Concernant le bouton _permuter les photos_ on pourrait affecter un **id** au bouton dans le code HTML puis réaliser l'abonnement de la fonction `permuter` en utilisant la même méthode qu'auparavant à savoir :
# ```js
#     document.getElementById("id_du_bouton").addEventListener("click",permuter);
# ```
# mais on va faire autrement ....
#
# 1. Ajouter la ligne de code suivante au fichier `script2.js`
#
# ```js
#     document.querySelector("button").addEventListener("click",permuter);
# ```
#
# 2. Faire de même pour l'abonnement des fonctions `popUp` et `reinitialiser` sur son élément cible
#
#
# 3. Tester le résultat dans le navigateur. Vous devriez constater un problème pour la fenêtre de popUp Contrairement à ce qu'on souhaite, celle-ci se déclenche sur un autre paragraphe (le tout premier du document HTML!!)
#
#
# ## Synthèse intermédiaire
#
# * La méthode `querySelector` permet de sélectionner le **premier** élément dans le document qui correspond au **sélecteur CSS** mentionné en paramètre. Le sélecteur utilisé ici correspond tout simplement au **nom de balise** concernée. (Si nécessaire revoir le cours sur le CSS pour plus d'informations sur les sélecteurs CSS)
#
#
# * Comme il n'y a qu'un seul bouton dans le document HTML : pas de problème
#
#
# * Dans le cas du paragraphe, cela sélectionne le **premier** paragraphe de la page web, qui n'est donc pas celui souhaité !!
#
# Pour informations, à part `getElementById` et `querySelector` d'autres méthodes javascript existent pour sélectionner les élément HTML cibles :
#
# |||
# |:-|:-|
# |`document.getElementsByClassName(nom_de_classe)`|sélectionne la **liste** des éléments ayant le nom de classe donné.|
# |`document.getElementsByTagName(nom_de_balise)`|sélectionne la **liste** des éléments ayant le nom de balise HTML donné.|
# |`document.getElementById(id)`|sélectionne l'élément identifié selon son **id**.|
# |`document.querySelector(sélecteur)`|sélectionne **LE PREMIER** élément dans le document, dans l'ordre du document, qui correspond au sélecteur CSS spécifié.|
# |`document.querySelectorAll(sélecteur)`|sélectionne la **liste** de TOUS les éléments inclus dans le document qui correspondent au sélecteur CSS spécifié. |
#
#
# ## Activité 12
#
# 1. Pour corriger le problème sur le paragraphe, remplacer la ligne de code concernée par celle ci-dessous :
#
# ```js
#     document.querySelector(".exemples p:first-child").addEventListener("click",popUp);
# ```
#
# 2. Tester le résultat dans le navigateur : tout devrait fonctionner !
#
#
# ## Synthèse intermédiaire
#
# * En paramètre de la fonction `querySelector`, on a passé un **sélecteur CSS** plus évolué : `".exemples p:first-child"` qui signifie _"premier paragraphe fils de la classe exemples"_.
#
#
# * Nous n'allons pas nous attarder ici sur ces sélecteurs CSS : nous en verrons quelques-uns plus tard...
#
#
# ## Activité 13
#
# 1. Dans le fichier `script2.js`, remplacer les fonctions `modifier Item` et `changeColor` par le code javascript suivant :
#
# ```js
# function modifierItem(){
#   this.innerHTML="...une fonction javascript qui le modifie";
# }
#
# function changeColor(){
#   this.style.color="blue";
# }
# ```
#
# 2. Tester : Tour devrait fonctionner
#
# ## Synthèse intermédiaire
#
# Dans une fonction **gestionnaire d'événement**, l'objet `this` est défini et **désigne l'élément HTML cible de l'événement**
#
# En effet grâce au code ci-dessous :
#
# ```js
#     document.getElementById("monItem1").addEventListener("dblclick",modifierItem);
#     document.getElementById("monItem2").addEventListener("mouseover",changeColor);
# ```
#
# nous avions abonné :
# * la fonction `modifierItem` à l'élément cible `"monItem1"` : donc pour `modifierItem`, `this` désigne l'lément d'ID `"monItem1"`
# * la fonction `changeColor` à l'élément cible `"monItem2"` : donc pour `changeColor`, `this` désigne l'lément d'ID `"monItem2"`
#
# et on peut donc remplacer le code
#
# ```js
# function modifierItem(){
#   document.getElementById("monItem1").innerHTML="...une fonction javascript qui le modifie";
# }
#
# function changeColor(){
#   document.getElementById("monItem2").style.color="blue";
# }
# ```
#
# par le code
#
# ```js
# function modifierItem(){
#   this.innerHTML="...une fonction javascript qui le modifie";
# }
#
# function changeColor(){
#   this.style.color="blue";
# }
# ```
#
#
# ## Activité 14
#
# > Quel est l'avantage procuré par l'utilisation de `this` ?
# Tout simplement, les fonctions peuvent être définies indépendamment d'un élément HTML particulier et peuvent donc servir (pour autant que l'abonnement a été réalisé) pour nimporte quel élément HTML.
#
# 1. Dans le fichier `script2.js`, ajouter le code suivant
#
# ```js
#     document.querySelector("button").addEventListener("mouseover",changeColor);
#     document.querySelector("strong").addEventListener("mouseover",changeColor);
# ```
#
# 2. Tester dans votre navigateur : Au survol de la souris, le texte du bouton doit apparaître en bleu ainsi que le **premier** élément `<strong>` (correspondant au mot _statiques_ dans le premier paragraphe du document). Et surtout, vous n'avez pas eu besoin de réécrire 2 fois la fonction `changeColor` pour ces 2 nouveaux éléments !!
