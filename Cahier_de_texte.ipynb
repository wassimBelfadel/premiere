# %% [markdown]
# # Séance 1 : ... septembre 2020 de ...h à ...h
# ## Activité en classe :
# * **Rentrée :**
# 	* (1) Création d'un _repository_ privé sur **github**
#
#
# * **bloc6/initiation_a_python**
# 	* (2) Cours Introduction au langage python
#     * (3) Cours Découverte de Python
#     * (4) TD Le shell de python
#     * (5) Cours Variable et types simples en python
#     * (6) TD les bases de python
#
#
# * **bloc1/ecriture_entier_positif**
# 	* (7) Cours Introduction à la représentation des données
#     * (8) TD_numeration
#
# ## Pour la prochaine séance :
#   * Lire les 7 fichiers disponibles dans informations_diverses. Ceux qui ne le font pas s'exposent à de désagréables surprises.
#   * Installer THONNY à la maison
#   * (Re)pratiquer les activités de la séance 1
#   * Terminer le TD les bases de python
#   * TD Numération : faire les exercices ........
#   * Dispositif "classe inversée" : lire le cours sur les appels de fonctions (bloc6) et l'HTML (bloc4)
#
# > **Rappel** :
# * *Evidemment commencer le travail la veille au soir, c'est trop tard !! Le dernier cours sera évidemment un lointain souvenir et vous allez trouver cela trop long : Il faut découper ce travail sur toute la semaine, un petit peu à la fois !*
# * *En informatique, les parties du programme ne sont pas indépendantes les unes des autres. Nous voyons en ce moment **les fondations** dont on se servira tout le temps après !*
# * _Apprendre son cours c'est bien mais c'est insuffisant : En python, le plus important c'est **la pratique**_
#
# # A venir..
#
# * appel de fonction P
# * html
# * definition de fonction P
# * linux : commandes de base
# * if P
# * css
# * bibliotheques P
# * representation texte x
# * operateurs booleens p
# * Architecture
# * boucles for P
# * javascript : événement
# * listes, tuple P
# * entier relatif x
# * Algorithmique : parcours séquentiel dans un tableau P
#
# notice markdown + notebook + mettre lien base de données QCM
#
# * droits OS libre vs propriétaire
# * dictionnaires P
# * protocole HTTP et interaction client / serveur
# * specification d'une fonction P
# * formulaire javascript + flask
# * tests P
# * Architecture d'un réseau, protocole paquet (bit alterné)
# * while P
# * flottant x
# * matrice liste en compréhension (ajouter des exercices sur la recherche sequentielle ds un tableau à 2 dimensions) P
# * arduino
# * IHM P
# * tables x
# * dichotomie P
# * algo knn x
# * tris P
# * gloutons x
