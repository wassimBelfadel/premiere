# %% [markdown]
# # Séance 9 : 25 septembre 2020 de 10h à 12h
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) TD numération : exercice 7
#
# * **bloc4/HTML**
#     * (2) Cours HTML
#     * (3)TD HTML Exercices 1
#
# ## Pour la prochaine séance :
# * Installer [ATOM](https://atom.io/) à la maison. Le télécharger. En cas de souci (improbable), vous pouvez installer [Notepad++](https://notepad-plus-plus.org/downloads/v7.8.8/).<br>
#  Bien faire attention à choisir la version de windows (64 ou 32 bits) correspondant à votre système d'exploitation
# * **bloc4/HTML**
#     * Commencer l'exercice 2 du TD HTML
# * **Evaluation de type QCM prévue le vendredi 09 octobre**. A revoir : bloc1 (tout) +  bloc6 (initiation à python + appels de fonction) et lire le fichier `/Informations_diverses/Epreuve_NSI_au_baccalaureat` pour avoir des informations sur la nature de l'épreuve.
#
#
#     * Faire un point sur ses faiblesses (sur le bloc1 et Python)
#     * Exercice complémentaire à la demande Samedi 2 Octobre.
#
#
# # Séance 8 : 25 septembre 2020 de 10h à 12h
# ## Activité en classe :
#
# * **bloc6/initiation_a_python**
#     * (1) TD_Les_bases_de_python.ipynb : correction exercice 10,11
#
# * **bloc6/fonctions**
#     * (2) cours appels de fonction (suite)
#     * (3) TD appels de fonctions : exercice 4
#
# ## Pour la prochaine séance :
# *  TD numération : exercice 7
#
# # Séance 7 : 24 septembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) correction TD numeration : Exercices 5
#     * (2) TD numeration : Exercices 6
#
# * **bloc6/fonctions**
#     * (3) cours appels de fonction
#     * (4) TD appel de fonctions : Exercices 1 et 2
#
# * **bloc6/initiation_a_python**
#     * (3) TD_Les_bases_de_python.ipynb : exercice 10,11
#
# ## Pour la prochaine séance :
#     * bloc6/fonctions/TD_appel_de_fonctions : Exercice 3
#
# # Séance 6 : 19 septembre 2020 de 10h à 12h
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) Correction TD numeration : Exercices 1.3
#     * (2) TD numeration : Exercices 2,3,4
#
# * **bloc6/initiation_a_python**
#     * (3) TD_Les_bases_de_python.ipynb : exercice 8,9
#
#
# ## Pour la prochaine séance :
#     * bloc1/TD numeration : Exercices 5
#
#
# # Séance 5 : 18 septembre 2020 de 8h à 10h
# ## Activité en classe :
#
# * **bloc1/ecriture_entier_positif**
#     * (1) correction TD numeration : Exercices 1.1 et 1.2
#
#
# * **bloc6/initiation_a_python**
#       (3) TD_Les_bases_de_python.ipynb : Correction exercice 5
#     * (2) TD_Les_bases_de_python.ipynb : exercice 6 ,7
#
#
# ## Pour la prochaine séance :
#
#     (1) TD numeration : Exercices 1.3
#
#
# # Séance 4 : 12 septembre 2020 de 10h à 12h
# ## Activité en classe :
#
# * **bloc1**
#     * (1) Cours_Introduction_a_la_representation_des_donnees.ipynb
#
# * **bloc1/ecriture_entier_positif**
#     * (2) cours_representation_entier_positif.ipynb
#     * (3) TD numeration Exercices 1 et 2
#
# ## Pour la prochaine séance :
#
#     * Revoir le cours de la séance 4
#     * Exercice :
#         Convertir le nombre "décimal" 45 en binaire et en hexadécimal.
#         Convertir le nombre "hexadécimal" F8 en binaire et en décimal.
#         Convertir le nombre "binare" 11000101 en décimal et en hexadécimal.
#
#
#
# # Séance 3: 11 septembre 2020 de 13h à 15h
# ## Activité en classe :
#
# * **bloc6/initiation_a_python**
#     * (1) Poursuite du TD_Les_bases_de_python.ipynb
#
# * **bloc1**
#     * (3) début Cours_Introduction_a_la_representation_des_donnees.ipynb
#
# ## Pour la prochaine séance :
#   * Faire sur feuille l'exercice 5 du TD_Les_bases_de_python.ipynb (pour cela, utiliser le Cours_Variables_et_types_simples_en_python)
#   * (Re)pratiquer / (Re)lire les activités de la séance 3
#
#
# > **Rappel** :
# * *En informatique, les parties du programme ne sont pas indépendantes les unes des autres. Nous voyons en ce moment **les fondations** dont on se servira tout le temps après !*
# * _Apprendre son cours c'est bien mais c'est insuffisant : En python, le plus important c'est **la pratique**_
#
# # Séance 2 : 5 septembre 2020 de 10h à 12h
# ## Activité en classe :
#
# * **bloc6/initiation_a_python**
# 	* (1) Cours_Variables_et_types_simples_en_python
#     * (2) TD_Les_bases_de_python.ipynb
#
# ## Pour la prochaine séance :
#   * Installer Thonny à la maison (Penser à ouvrir le fichier `premiere/Outils_et_environnement_informatiques/Thonny` si nécessaire)
#   * (Re)pratiquer / (Re)lire les activités de la séance 2
#
# > **Rappel** :
# * *En informatique, les parties du programme ne sont pas indépendantes les unes des autres. Nous voyons en ce moment **les fondations** dont on se servira tout le temps après !*
# * _Apprendre son cours c'est bien mais c'est insuffisant : En python, le plus important c'est **la pratique**_
#
#
# # Séance 1 : 4 septembre 2020 de 13h à 15h
# ## Activité en classe :
# * **Rentrée :**
#     * (1) Questionnaire de rentrée (connaissance en informatique)
# 	* (2) Création d'un _repository_ privé sur **github**
#
#
# * **bloc6/initiation_a_python**
# 	* (3) Cours Introduction au langage python
#     * (4) Cours Découverte de Python
#     * (5) TD Le shell de python
#
# ## Pour la prochaine séance :
#   * Lire les 7 fichiers d'extension `.ipynb` disponibles dans informations_diverses (De désagréables surprises attendent ceux qui ne le font pas).
#   * Installer THONNY à la maison
#   * (Re)pratiquer les activités de la séance 1
#   * Dispositif "classe inversée" : lire le cours "Variable et types simples en python" (bloc6)
#
# > **Rappel** :
# * *Evidemment commencer le travail la veille au soir, c'est trop tard !! Le dernier cours sera évidemment un lointain souvenir et vous allez trouver cela trop long : Il faut découper ce travail sur toute la semaine, un petit peu à la fois !*
# * *En informatique, les parties du programme ne sont pas indépendantes les unes des autres. Nous voyons en ce moment **les fondations** dont on se servira tout le temps après !*
# * _Apprendre son cours c'est bien mais c'est insuffisant : En python, le plus important c'est **la pratique**_
#
# # A venir..
#
# * Variables et type en python P
# * Numeration
# * appel de fonction P
# * html
# * definition de fonction P
# * linux : commandes de base
# * if P
# * css
# * bibliotheques P
# * representation texte x
# * operateurs booleens p
# * Architecture
# * boucles for P
# * javascript : événement
# * listes, tuple P
# * entier relatif x
# * Algorithmique : parcours séquentiel dans un tableau P
#
# notice markdown + notebook + mettre lien base de données QCM
#
# * droits OS libre vs propriétaire AF
# * dictionnaires P AF
# * protocole HTTP et interaction client / serveur
# * specification d'une fonction P
# * formulaire javascript + flask
# * tests P AF*
# * Architecture d'un réseau, protocole paquet (bit alterné) AF
# * while P  AF
# * flottant x
# * matrice liste en compréhension (ajouter des exercices sur la recherche sequentielle ds un tableau à 2 dimensions) P AF
# * arduino AF
# * tables x
# * dichotomie P AF
# * algo knn x
# * tris P
# * gloutons x
#
# projet :
# * IHM TkibterP AF *
