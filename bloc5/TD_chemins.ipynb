# %% [markdown]
# # TD chemins et arborescence de fichier
#
# > Dans les arborescences de ce TD :
# * les dossiers sont encadrés
# * les fichiers ne sont pas encadrés<br><br>
# **Ce TD illustre notamment le fait que programmation et arborescence de fichiers sont intimement liés : les fameuses `FileNotFoundError` en python, les hyperliens qui ne fonctionnent pas, les images d'un site web qui ne s'affichent pas ou encore les `Erreur : No such file or directory` etc...
# Il y a bien d'autres dysfonctionnements et erreurs possibles, dûs non pas à une erreur de programmation, mais à une mauvaise gestion de l'arborescence de fichier et un problème d'organisation**
#
# ## Exercice 1
#
# ![arbo 3](img/arbo3.png)
#
# 1. Combien y a t-il de répertoire(s) ?
# 2. Combien y a t-il de répertoire(s) vide(s) ?
# 3. Combien y a t-il de fichier(s) ?
# 4. Comment s'appelle le répertoire racine ?
# 5. Quel est le **symbole** utilisé pour séparer les éléments (dossiers ou fichiers) entre eux dans un chemin informatique ?
# 6. Quel est le **chemin absolu** permettant d'accéder au fichier `vacances.png`
# 7. Quel est le **chemin relatif** permettant d'accéder au fichier `vacances.png` depuis le répertoire `Bob` ?
#
#
# Votre répertoire courant est le répertoire `/commun`. En utilisant uniquement des **chemins ABSOLUS**, pour chaque question ci-dessous, écrire **UNE SEULE** ligne de commande _shell Linux_ permettant de réaliser l'action demandée
#
# 1. Créer un répertoire `tmp` dans `Bob`
# 2. Déplacer le fichier `rapport.txt` dans `commun`
# 3. ouvrir le fichier `index.html` avec l'éditeur de texte **nano**
# 4. Renommer le fichier `plan.png` en `itineraire.png`
# 5. Supprimer le fichier `prog.py`
# 6. faire une copie du fichier `bilan.csv` dans le dossier `doc` de `commun`
# 7. Afficher le contenu du répertoire `comptabilité`
# 8. Supprimer le dossier `img`
# 9. Créer un fichier (vide) `temp.txt` dans `comptabilite`
#
#
# ## Exercice 2
#
# 1. Pourquoi dans la conception d'un site web doit-on uniquement utiliser des chemins **relatifs** et non absolus ?
# *(Indication : Penser au moment où le site est mis en ligne chez un hébergeur...*)
#
# > Pour cette raison, le nom du répertoire "racine" n'est pas donné (et ce n'est pas à vous de le rajouter...) car on n'en a pas besoin !
#
# ![arbo 1](img/arbo1.png)
#
# 2. Compléter le fichier `index.html` ci-dessous pour que le site fonctionne relativement à l'arborescence ci dessus
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>index</title>
#
#     <!-- lien avec la feuille de style : style.css -->
#     <link rel="stylesheet" href="">
#   </head>
#   <body>
#     <p>Bienvenue sur mon site</p>
#
#     <!-- hyperlien vers page1.html -->
#     cliquer <a href="">ici</a>
#
#     <!-- insérer l'image1 -->
#     <img src="">
#
#     <!-- insérer l'image2 -->
#     <img src="">
#   </body>
# </html>
# ```
#
# ## Exercice 3
#
# ![arbo 3](img/arbo3.png)
#
# Votre répertoire courant est le répertoire `/commun`. En utilisant uniquement des **chemins RELATIFS**, pour chaque question ci-dessous, écrire **UNE SEULE** ligne de commande _shell Linux_ permettant de réaliser l'action demandée
#
# 1. Créer un répertoire `tmp` dans `Bob`
# 2. Déplacer le fichier `rapport.txt` dans `commun`
# 3. ouvrir le fichier `index.html` avec l'éditeur de texte **nano**
# 4. Renommer le fichier `plan.png` en `itineraire.png`
# 5. Supprimer le fichier `prog.py`
# 6. faire une copie du fichier `bilan.csv` dans le dossier `doc` de `commun`
# 7. Afficher le contenu du répertoire `comptabilité`
# 8. Supprimer le dossier `img`
# 9. Créer un fichier (vide) `temp.txt` dans `comptabilite`
#
# ## Exercice 4
#
# > On rappelle qu'il ne faut utiliser que des chemins **relatifs** et non absolus
#
# Dessiner l'arborescence pour que la page web `index.html` ci-dessous fonctionne correctement
#
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>index</title>
#
#     <!-- lien avec la feuille de style : style.css -->
#     <link rel="stylesheet" href="doc/style/style.css">
#   </head>
#   <body>
#     <p>Bienvenue sur mon site</p>
#
#     <!-- hyperlien vers page1.html -->
#     cliquer <a href="page1.html">ici</a>
#
#     <!-- insérer l'image1 -->
#     <img src="doc/image/image1.jpg">
#
#     <!-- insérer l'image2 -->
#     <img src="doc/image/image2.png">
#   </body>
# </html>
# ```
#
#
#
# ## Exercice 5
#
# ![arbo 3](img/arbo3.png)
#
# Votre répertoire courant est le répertoire `/Alice/doc`. En utilisant uniquement des **chemins ABSOLUS**, pour chaque question ci-dessous, écrire **UNE SEULE** ligne de commande _shell Linux_ permettant de réaliser l'action demandée
#
# 1. Créer un répertoire `tmp` dans `Bob`
# 2. Déplacer le fichier `rapport.txt` dans `commun`
# 3. ouvrir le fichier `index.html` avec l'éditeur de texte **nano**
# 4. Renommer le fichier `plan.png` en `itineraire.png`
# 5. Supprimer le fichier `prog.py`
# 6. faire une copie du fichier `bilan.csv` dans le dossier `doc` de `commun`
# 7. Afficher le contenu du répertoire `comptabilité`
# 8. Supprimer le dossier `img`
# 9. Créer un fichier (vide) `temp.txt` dans `comptabilite`
#
# ## Exercice 6
#
# > On rappelle qu'il ne faut utiliser que des chemins **relatifs** et non absolus
#
# ![arbo 2](img/arbo2.png)
#
# Compléter le fichier **`index.html`** ci-dessous pour que le site fonctionne relativement à l'arborescence ci dessus
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>index</title>
#
#     <!-- lien avec la feuille de style : style.css -->
#     <link rel="stylesheet" href="">
#   </head>
#   <body>
#     <p>Bienvenue sur mon site</p>
#
#     <!-- hyperlien vers page1.html -->
#     cliquer <a href="">ici</a> pour aller vers la page1
#
#     <!-- hyperlien vers page2.html -->
#     cliquer <a href="">ici</a> pour aller vers la page2
#
#     <!-- insérer l'image1 -->
#     <img src="">
#
#     <!-- insérer l'image2 -->
#     <img src="">
#
#     <!-- insérer l'image3 -->
#     <img src="">
#   </body>
# </html>
# ```
#
# Compléter le fichier **`page1.html`** ci-dessous pour que le site fonctionne relativement à l'arborescence ci dessus
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>page1</title>
#
#     <!-- lien avec la feuille de style : style.css -->
#     <link rel="stylesheet" href="">
#   </head>
#   <body>
#     <p>Bienvenue sur ma page1</p>
#
#     <!-- hyperlien vers index.html -->
#     cliquer <a href="">ici</a> pour aller vers l'index
#
#     <!-- hyperlien vers page2.html -->
#     cliquer <a href="">ici</a> pour aller vers la page2
#
#     <!-- insérer l'image1 -->
#     <img src="">
#
#     <!-- insérer l'image2 -->
#     <img src="">
#
#     <!-- insérer l'image3 -->
#     <img src="">
#   </body>
# </html>
# ```
#
# Compléter le fichier **`page2.html`** ci-dessous pour que le site fonctionne relativement à l'arborescence ci dessus
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>page1</title>
#
#     <!-- lien avec la feuille de style : style.css -->
#     <link rel="stylesheet" href="">
#   </head>
#   <body>
#     <p>Bienvenue sur ma page2</p>
#
#     <!-- hyperlien vers index.html -->
#     cliquer <a href="">ici</a> pour aller vers l'index
#
#     <!-- hyperlien vers page1.html -->
#     cliquer <a href="">ici</a> pour aller vers la page1
#
#     <!-- insérer l'image1 -->
#     <img src="">
#
#     <!-- insérer l'image2 -->
#     <img src="">
#
#     <!-- insérer l'image3 -->
#     <img src="">
#   </body>
# </html>
# ```
#
# ## Exercice 7
#
# ![arbo 3](img/arbo3.png)
#
# Votre répertoire courant est le répertoire `/Alice/doc`. En utilisant uniquement des **chemins RELATIFS**, pour chaque question ci-dessous, écrire **UNE SEULE** ligne de commande _shell Linux_ permettant de réaliser l'action demandée
#
# 1. Créer un répertoire `tmp` dans `Bob`
# 2. Déplacer le fichier `rapport.txt` dans `commun`
# 3. ouvrir le fichier `index.html` avec l'éditeur de texte **nano**
# 4. Renommer le fichier `plan.png` en `itineraire.png`
# 5. Supprimer le fichier `prog.py`
# 6. faire une copie du fichier `bilan.csv` dans le dossier `doc` de `commun`
# 7. Afficher le contenu du répertoire `comptabilité`
# 8. Supprimer le dossier `img`
# 9. Créer un fichier (vide) `temp.txt` dans `comptabilite`
#
# ## Exercice 8
#
# > Si nécessaire, relire le cours `bloc6/bibliotheques/Cours_bibliotheques`, notamment la fin sur les packages en python.
#
# ![arbo 4](img/arbo4.png)
#
# > Alice et Bob ont réalisé un projet python. Comme Ils sont bien organisés, ils ont "découpé" le projet en fonctions puis se sont réparti entre eux les fonctions à coder. Alice et Bob travaillent dans leur répertoire personnel respectif et ils ont tous les deux rassemblé leurs fonctions dans 2 fichiers (en fonction du rôle de chaque fonction).
# Toutes les fonctions ayant été codées puis testées, il est venu le temps de finaliser le travail et d'"assembler" le tout dans un fichier `principal.py`. Le découpage du projet est visible dans l'arborescence ci-dessus
#
# **Toutes les lignes de code demandées dans cet exercice sont des lignes de code du fichier `principal.py`**
#
# 1. Combien de modules python, Alice et Bob ont-ils écrit en tout pour réaliser leur projet ?
# 2. Ecrire la/les ligne(s) de code python (écrite(s) dans le fichier `principal.py`) permettant d'importer tous ces modules
#
# > Dans le fichier `cartographie.py`, Alice a notamment écrit une fonction `afficherCarte`. Dans le fichier `score.py`, Bob a notamment écrit une fonction `afficherScore`. Ces deux fonctions ne prennent aucun paramètre.
#
# 3. Ecrire la ligne de code python (écrite dans le fichier `principal.py`) permettant d'appeler la fonction `afficherCarte` et la ligne de code python permettant d'appeler la fonction `afficherScore`
#
# 4. Refaire la question 2 et 3 en mettant en place des **alias** permettant de "raccourcir" l'écriture des appels des 2 fonctions
#
# > On souhaite maintenant que les appels aux fonctions `afficherCarte` et `afficherScore` se fasse simplement en écrivant les lignes de codes suivantes :
# ```python
# afficherCarte()
# afficherScore()
# ```
#
# 5. Réécrire la/les ligne(s) de code python d'**importation** permettant cela.
